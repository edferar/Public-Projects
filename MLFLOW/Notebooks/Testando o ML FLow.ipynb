# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Housing.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7229300521  20141013T000000  231300.0         2       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df_clean = df[['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 
       'lat', 'long', 'sqft_living15', 'sqft_lot15']].copy()

# %%
X = df_clean.drop('price',axis=1)
y = df_clean['price'].copy()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import mlflow

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")

# %%
mlflow.set_experiment('house-pott')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/265932537066601344', creation_time=1719358148645, experiment_id='265932537066601344', last_update_time=1719358148645, lifecycle_stage='active', name='house-pottencial', tags={}>

# %% [markdown]
# # Linear Regression

# %%
mlflow.start_run()
# Out:
# <ActiveRun: >

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
mlflow.sklearn.log_model(lr,'lr')

# %%
lr_predicted = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
import math

mse = mean_squared_error(y_test, lr_predicted)
rmse =  math.sqrt(mse)
r2 = r2_score(y_test, lr_predicted)
mlflow.log_metric('mse',mse)
mlflow.log_metric('rmse',rmse)
mlflow.log_metric('r2',r2)

# %%
mlflow.end_run()

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBRFRegressor, XGBRegressor

# %%
with mlflow.start_run():
    xgb = XGBRegressor()
    xgb.fit(X_train, y_train)
    mlflow.xgboost.log_model(xgb,'xgboost')
    xgb_predicted = xgb.predict(X_test)
    mse = mean_squared_error(y_test, xgb_predicted)
    rmse =  math.sqrt(mse)
    r2 = r2_score(y_test, xgb_predicted)
    mlflow.log_metric('mse',mse)
    mlflow.log_metric('rmse',rmse)
    mlflow.log_metric('r2',r2)
# Out:
# c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:30:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
xgb_params = {
    'learning_rate':0.2,
    'n_estimators': 50,
    'random_state':42
}

with mlflow.start_run():
    xgb = XGBRegressor(**xgb_params)
    xgb.fit(X_train, y_train)
    mlflow.xgboost.log_model(xgb,'xgboost-tunning')
    xgb_predicted = xgb.predict(X_test)
    mse = mean_squared_error(y_test, xgb_predicted)
    rmse =  math.sqrt(mse)
    r2 = r2_score(y_test, xgb_predicted)
    mlflow.log_metric('mse',mse)
    mlflow.log_metric('rmse',rmse)
    mlflow.log_metric('r2',r2)
    mlflow.log_param('random_state',42)
# Out:
# c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:30:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
xgb_params = {
    'learning_rate':0.2,
    'n_estimators': 50,
    'random_state':42
}

with mlflow.start_run():
    xgb = XGBRFRegressor(**xgb_params)
    xgb.fit(X_train, y_train)
    mlflow.xgboost.log_model(xgb,'xgbrfr-tunning')
    xgb_predicted = xgb.predict(X_test)
    mse = mean_squared_error(y_test, xgb_predicted)
    rmse =  math.sqrt(mse)
    r2 = r2_score(y_test, xgb_predicted)
    mlflow.log_metric('mse',mse)
    mlflow.log_metric('rmse',rmse)
    mlflow.log_metric('r2',r2)
    mlflow.log_params(xgb_params)
# Out:
# c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:30:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-06abd128ca6c1688d-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
mlflow.get_experiment_by_name('house-pottencial')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/265932537066601344', creation_time=1719358148645, experiment_id='265932537066601344', last_update_time=1719358148645, lifecycle_stage='active', name='house-pottencial', tags={}>

# %%
mlflow.get_run('c7e2607ab3084fa18b4d87e55dcf1c65')
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mlflow.get_run('c7e2607ab3084fa18b4d87e55dcf1c65')
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\tracking\fluent.py:590, in get_run(run_id)
#     558 def get_run(run_id: str) -> Run:
#     559     """
#     560     Fetch the run from backend store. The resulting Run contains a collection of run metadata --
#     561     RunInfo as well as a collection of run parameters, tags, and metrics -- RunData. It also
#    (...)
#     588         run_id: 7472befefc754e388e8e922824a0cca5; lifecycle_stage: active
#     589     """
# --> 590     return MlflowClient().get_run(run_id)
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\tracking\client.py:226, in MlflowClient.get_run(self, run_id)
#     182 def get_run(self, run_id: str) -> Run:
#     183     """
#     184     Fetch the run from backend store. The resulting :py:class:`Run <mlflow.entities.Run>`
#     185     contains a collection of run metadata -- :py:class:`RunInfo <mlflow.entities.RunInfo>`,
#    (...)
#     224
#     225     """
# --> 226     return self._tracking_client.get_run(run_id)
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:102, in TrackingServiceClient.get_run(self, run_id)
#      86 """Fetch the run from backend store. The resulting :py:class:`Run <mlflow.entities.Run>`
#      87 contains a collection of run metadata -- :py:class:`RunInfo <mlflow.entities.RunInfo>`,
#      88 as well as a collection of run parameters, tags, and metrics --
#    (...)
#      99
#     100 """
#     101 _validate_run_id(run_id)
# --> 102 return self.store.get_run(run_id)
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\tracking\rest_store.py:165, in RestStore.get_run(self, run_id)
#     155 """
#     156 Fetch the run from backend store
#     157
#    (...)
#     162     A single Run object if it exists, otherwise raises an Exception
#     163 """
#     164 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 165 response_proto = self._call_endpoint(GetRun, req_body)
#     166 return Run.from_proto(response_proto.run)
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\store\tracking\rest_store.py:81, in RestStore._call_endpoint(self, api, json_body, endpoint)
#      79     endpoint, method = _METHOD_TO_INFO[api]
#      80 response_proto = api.Response()
# ---> 81 return call_endpoint(self.get_host_creds(), endpoint, method, json_body, response_proto)
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\utils\rest_utils.py:304, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers)
#     301     call_kwargs["json"] = json_body
#     302     response = http_request(**call_kwargs)
# --> 304 response = verify_rest_response(response, endpoint)
#     305 js_dict = json.loads(response.text)
#     306 parse_dict(js_dict=js_dict, message=response_proto)
#
# File c:\Users\silva\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\utils\rest_utils.py:174, in verify_rest_response(response, endpoint)
#     172 if response.status_code != 200:
#     173     if _can_parse_as_json_object(response.text):
# --> 174         raise RestException(json.loads(response.text))
#     175     else:
#     176         base_msg = (
#     177             f"API request to endpoint {endpoint} "
#     178             f"failed with error code {response.status_code} != 200"
#     179         )
#
# RestException: RESOURCE_DOES_NOT_EXIST: Run 'c7e2607ab3084fa18b4d87e55dcf1c65' not found
